# %%
# !pip install dtreeviz
# Out:
# Requirement already satisfied: dtreeviz in c:\users\hp technology\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: graphviz>=0.9 in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (0.20.3)
# Requirement already satisfied: pandas in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (2.1.4)
# Requirement already satisfied: numpy in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (1.2.2)
# Requirement already satisfied: matplotlib in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (3.8.0)
# Requirement already satisfied: colour in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (0.1.5)
# Requirement already satisfied: pytest in c:\users\hp technology\anaconda3\lib\site-packages (from dtreeviz) (7.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp technology\anaconda3\lib\site-packages (from matplotlib->dtreeviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp technology\anaconda3\lib\site-packages (from pandas->dtreeviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp technology\anaconda3\lib\site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: iniconfig in c:\users\hp technology\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\hp technology\anaconda3\lib\site-packages (from pytest->dtreeviz) (1.0.0)
# Requirement already satisfied: colorama in c:\users\hp technology\anaconda3\lib\site-packages (from pytest->dtreeviz) (0.4.6)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\hp technology\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\hp technology\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp technology\anaconda3\lib\site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\hp technology\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)

# %%
import graphviz.backend as be
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 1. Classification

# %%
import dtreeviz


viz = dtreeviz(clas, 
               X_train,
               y_train,
               feature_names=iris.feature_names, )
viz.view()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 import dtreeviz
# ----> 4 viz = dtreeviz(clas,
#       5                X_train,
#       6                y_train,
#       7                feature_names=iris.feature_names, )
#       8 viz.view()
#
# TypeError: 'module' object is not callable
